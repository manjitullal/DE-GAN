# %% [markdown]
# <a href="https://colab.research.google.com/github/manjitullal/DE-GAN/blob/main/DE_GAN_degrade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DE GAN
#
# https://arxiv.org/abs/2010.08764
#
# https://arxiv.org/abs/1406.2661

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/07/84/46421bd3e0e89a92682b1a38b40efc22dafb6d8e3d947e4ceefd4a5fabc7/tensorboardX-2.2-py2.py3-none-any.whl (120kB)
#      |████████████████████████████████| 122kB 12.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.19.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.12.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (54.2.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorboardX) (1.15.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.2

# %%
# !wget https://raw.githubusercontent.com/diegoalejogm/gans/master/utils.py
# Out:
# --2021-04-21 02:07:32--  https://raw.githubusercontent.com/diegoalejogm/gans/master/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4866 (4.8K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   4.75K  --.-KB/s    in 0s
#
# 2021-04-21 02:07:32 (66.2 MB/s) - ‘utils.py’ saved [4866/4866]

# %%
# download the image degrade and binariser images 

# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00318/NoisyOffice.zip
# !unzip /content/NoisyOffice.zip
# Out:
# --2021-04-21 02:09:23--  https://archive.ics.uci.edu/ml/machine-learning-databases/00318/NoisyOffice.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 446643512 (426M) [application/x-httpd-php]
# Saving to: ‘NoisyOffice.zip’
#
# NoisyOffice.zip     100%[===================>] 425.95M  19.7MB/s    in 23s
#
# 2021-04-21 02:09:47 (18.6 MB/s) - ‘NoisyOffice.zip’ saved [446643512/446643512]
#
# Archive:  /content/NoisyOffice.zip
#    creating: NoisyOffice/
#   inflating: NoisyOffice/NoisyOffice_icon.png
#    creating: NoisyOffice/SimulatedNoisyOffice/
#    creating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontftm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontftm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLtm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontntm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnte_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLtm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontntm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontnsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfte_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontfrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontntm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/Fontftm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLtm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_binaryscale/FontLte_Clean_TR.png
#    creating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontftm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontftm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLtm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontntm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnte_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLtm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontntm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontnsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfte_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontfrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontntm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/Fontftm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLtm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale_doubleresolution/FontLte_Clean_TR.png
#    creating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfsm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfte_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfrm_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLsm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLtm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLte_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisew_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisep_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisep_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontntm_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnre_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontftm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnsm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfre_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisec_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnse_Noisew_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLre_Noisep_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLse_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisec_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisef_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontfse_Noisef_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisec_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnte_Noisef_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/FontLrm_Noisew_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/simulated_noisy_images_grayscale/Fontnrm_Noisep_VA.png
#    creating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontftm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnre_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontftm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLtm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontntm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnte_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLse_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLtm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLte_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLre_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfsm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnsm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfse_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontntm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnrm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLte_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnre_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfse_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontnsm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfte_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontfrm_Clean_VA.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontntm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLrm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/Fontftm_Clean_TR.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLtm_Clean_TE.png
#   inflating: NoisyOffice/SimulatedNoisyOffice/clean_images_grayscale/FontLte_Clean_TR.png
#    creating: NoisyOffice/RealNoisyOffice/
#    creating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnre_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnre_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLsm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnte_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLre_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLse_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfrm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontftm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfrm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfre_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLre_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontftm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLte_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfrm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfse_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnse_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontntm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnrm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnsm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontntm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfre_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontntm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLrm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLtm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLte_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLte_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnre_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontntm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnrm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfse_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnsm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLsm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnte_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfsm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLre_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfse_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfte_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLsm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnsm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnse_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnrm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontftm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfte_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLsm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfre_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnre_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfrm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLse_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontftm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfre_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLse_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLtm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnrm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfse_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnte_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLre_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnsm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLrm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLrm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfte_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLtm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfsm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfsm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfte_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLtm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontfsm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnse_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnte_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLse_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/Fontnse_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLte_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale_doubleresolution/FontLrm_Noisep_RE.png
#    creating: NoisyOffice/RealNoisyOffice/.xvpics/
#   inflating: NoisyOffice/RealNoisyOffice/.xvpics/text_cafec13.png
#   inflating: NoisyOffice/RealNoisyOffice/.xvpics/test_cafec13.png
#    creating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnre_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnre_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLsm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnte_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLre_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLse_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfrm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontftm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfrm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfre_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLre_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontftm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLte_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfrm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfse_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnse_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontntm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnrm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnsm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontntm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfre_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontntm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLrm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLtm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLte_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLte_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnre_Noisep_RE.png
#    creating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/.xvpics/
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/.xvpics/text_cafec13.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/.xvpics/test_cafec13.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontntm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnrm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfse_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnsm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLsm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnte_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfsm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLre_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfse_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfte_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLsm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnsm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnse_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnrm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontftm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfte_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLsm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfre_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnre_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfrm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLse_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontftm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfre_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLse_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLtm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnrm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfse_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnte_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLre_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnsm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLrm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLrm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfte_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLtm_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfsm_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfsm_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfte_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLtm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontfsm_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnse_Noisef_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnte_Noisew_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLse_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/Fontnse_Noisep_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLte_Noisec_RE.png
#   inflating: NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale/FontLrm_Noisep_RE.png
#   inflating: NoisyOffice/README_NoisyOffice.txt

# %% [markdown]
# ## import

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter
import numpy as np
from PIL import ImageFont, ImageDraw, ImageOps
from random import randint
import matplotlib.font_manager as fm
import pandas as pd
from IPython import display
from utils import Logger

import torch
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torchsummary import summary

# %%
from google.colab import drive
drive.mount('/content/drive') 

path = '/content/drive/MyDrive/Projects/CS7150/final/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Degraded Images

# %%
DATA_FOLDER = '/content/NoisyOffice/RealNoisyOffice/real_noisy_images_grayscale'

all_files = os.listdir(DATA_FOLDER)
all_files.remove('.xvpics')
all_files.sort()
all_files_path = [os.path.join(DATA_FOLDER, filename) for filename in all_files]
all_files_df = pd.DataFrame({'path': all_files_path, 'file_name': all_files})
all_files_df.head()
# Out:
#                                                 path              file_name
# 0  /content/NoisyOffice/RealNoisyOffice/real_nois...  FontLre_Noisec_RE.png
# 1  /content/NoisyOffice/RealNoisyOffice/real_nois...  FontLre_Noisef_RE.png
# 2  /content/NoisyOffice/RealNoisyOffice/real_nois...  FontLre_Noisep_RE.png
# 3  /content/NoisyOffice/RealNoisyOffice/real_nois...  FontLre_Noisew_RE.png
# 4  /content/NoisyOffice/RealNoisyOffice/real_nois...  FontLrm_Noisec_RE.png

# %%
degraded_df = all_files_df[all_files_df['file_name'].str.contains('Noisec_RE')]
clean_df = all_files_df[all_files_df['file_name'].str.contains('Noisef_RE')]

# %%
degraded_df = degraded_df.reset_index(drop=True)
clean_df = clean_df.reset_index(drop=True)

# %% [markdown]
# ## sample images

# %%
def image_resize(img):
  basewidth = 1200  
  hsize = 900
  # wpercent = (basewidth / float(img.size[0]))
  # hsize = int((float(img.size[1]) * float(wpercent)))
  img = img.resize((basewidth, hsize), Image.ANTIALIAS)
  return img

# %%
random_number = np.random.randint(0,18)

clean_image = Image.open(clean_df.loc[random_number][0])
clean_image = np.asarray(image_resize(clean_image))
clean_image = clean_image[:,:,1]

degraded_image = Image.open(degraded_df.loc[random_number][0])
degraded_image = np.asarray(image_resize(degraded_image))
degraded_image = degraded_image[:,:,1]

print(clean_image.shape, degraded_image.shape)
print()
_, ax = plt.subplots(1,2, figsize=(20,10))
ax[0].imshow(clean_image, cmap='gray')
ax[0].title.set_text('Clean Image')

ax[1].imshow(degraded_image, cmap='gray')
ax[1].title.set_text('Degraded Image')
plt.show()
# Out:
# (900, 1200) (900, 1200)

# %% [markdown]
# ## create patches
#
# original dataset is quite small with only 100 images. to create a bigger dataset create patches of images from the original dataset.

# %%
def getPatches(watermarked_image,clean_image,mystride):
    watermarked_patches=[]
    clean_patches=[]
        
    h =  ((watermarked_image.shape [0] // 256) +1)*256 
    w =  ((watermarked_image.shape [1] // 256 ) +1)*256
    image_padding=np.ones((h,w))
    image_padding[:watermarked_image.shape[0],:watermarked_image.shape[1]]=watermarked_image
    
    for j in range (0,h-256,mystride):  #128 not 64
        for k in range (0,w-256,mystride):
            watermarked_patches.append(image_padding[j:j+256,k:k+256])
    
    h =  ((clean_image.shape [0] // 256) +1)*256 
    w =  ((clean_image.shape [1] // 256 ) +1)*256

    image_padding=np.ones((h,w))
    image_padding[:clean_image.shape[0],:clean_image.shape[1]]=clean_image

    for j in range (0,h-256,mystride):    #128 not 64
        for k in range (0,w-256,mystride):
            clean_patches.append(image_padding[j:j+256,k:k+256])  
            
    return np.array(watermarked_patches),np.array(clean_patches)

# %%
# %%time
_degraded_patches , _cleanimage_patches = getPatches(degraded_image, clean_image, mystride=128+64)
print(_degraded_patches.shape, _cleanimage_patches.shape)
# Out:
# (24, 256, 256) (24, 256, 256)
# CPU times: user 11.3 ms, sys: 7.98 ms, total: 19.3 ms
# Wall time: 18.1 ms

# %%
def create_patches():
  degraded_patches = []
  clean_patches = []

  for i in range(degraded_df.shape[0]):
    clean_image = Image.open(clean_df.loc[i][0])
    clean_image = np.asarray(image_resize(clean_image))
    clean_image = clean_image[:,:,1]

    degraded_image = Image.open(degraded_df.loc[i][0])
    degraded_image = np.asarray(image_resize(degraded_image))
    degraded_image = degraded_image[:,:,1]

    _degraded_patches , _clean_patches = getPatches(degraded_image, clean_image, mystride=128+64)
    degraded_patches.append(_degraded_patches)    
    clean_patches.append(_clean_patches)

  degraded_patches = np.concatenate(degraded_patches, axis=0)
  clean_patches = np.concatenate(clean_patches, axis=0)

  return degraded_patches, clean_patches

# %%
# %%time

degraded_patches, clean_patches = create_patches()
# Out:
# CPU times: user 3.91 s, sys: 245 ms, total: 4.16 s
# Wall time: 4.14 s

# %%
print(degraded_patches.shape, clean_patches.shape)
# Out:
# (432, 256, 256) (432, 256, 256)

# %% [markdown]
# ## create dataset

# %%
class degraded(Dataset):

  def __init__(self, degraded_patches, clean_patches, transform=None):
    self.clean_patches = clean_patches
    self.degraded_patches = degraded_patches
    self.transform = transform

  def __len__(self):
    return len(self.clean_patches)

  def __getitem__(self, idx):
    clean_image = self.clean_patches[idx]
    degraded_image = self.degraded_patches[idx]

    clean_image = np.asarray(clean_image)
    degraded_image = np.asarray(degraded_image)

    clean_image = Image.fromarray(clean_image.astype(np.uint8))
    degraded_image = Image.fromarray(degraded_image.astype(np.uint8))

    if self.transform:
       clean_image = self.transform(clean_image)
       degraded_image = self.transform(degraded_image)

    return degraded_image, clean_image

dataset = degraded(degraded_patches, clean_patches, transform=transforms.Compose(
            [transforms.ToTensor(), 
             transforms.Normalize([0.5], [0.5])]))

bs = 16
data_loader = DataLoader(dataset, batch_size=bs, shuffle=True)
num_batches = len(data_loader)

# %%
x,y = next(iter(data_loader))
_, ax = plt.subplots(1,2)
ax[0].imshow(x[0].squeeze(), cmap='gray')
ax[1].imshow(y[0].squeeze(), cmap='gray')
plt.show()

# %%
print(x.shape, y.shape)
# Out:
# torch.Size([16, 1, 256, 256]) torch.Size([16, 1, 256, 256])

# %% [markdown]
# ## generator

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.conv(x)

class GeneratorNet(nn.Module):
    def __init__(
            self, in_channels=3, out_channels=1, features=[64, 128, 256, 512],
    ):
        super(GeneratorNet, self).__init__()
        self.ups = nn.ModuleList()
        self.downs = nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Down part of UNET
        for feature in features:
            self.downs.append(DoubleConv(in_channels, feature))
            in_channels = feature

        # Up part of UNET
        for feature in reversed(features):
            self.ups.append(
                nn.ConvTranspose2d(
                    feature*2, feature, kernel_size=2, stride=2,
                )
            )
            self.ups.append(DoubleConv(feature*2, feature))

        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)

    def forward(self, x):
        skip_connections = []

        for down in self.downs:
            x = down(x)
            skip_connections.append(x)
            x = self.pool(x)

        x = self.bottleneck(x)
        skip_connections = skip_connections[::-1]

        for idx in range(0, len(self.ups), 2):
            x = self.ups[idx](x)
            skip_connection = skip_connections[idx//2]

            if x.shape != skip_connection.shape:
                x = TF.resize(x, size=skip_connection.shape[2:])

            concat_skip = torch.cat((skip_connection, x), dim=1)
            x = self.ups[idx+1](concat_skip)

        return self.final_conv(x)
    
def images_to_vectors(images):
    return images.view(images.size(0), 784)

def vectors_to_images(vectors):
    return vectors.view(vectors.size(0), 1, 256, 256)

# %%
# summary(generator, (1,256,256))

# %% [markdown]
# ## discriminator

# %%
class DiscriminatorNet(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        self.disc = nn.Sequential(            
            nn.Conv2d(in_channels, 64, 3, 1, 1), # layer 1 64x256x256
            nn.LeakyReLU(0.01, inplace=True),                     
            nn.MaxPool2d(2),                     # layer 2 64x128x128
            nn.Conv2d(64, 128, 3, 1, 1),         # layer 3 128x128x128
            nn.LeakyReLU(0.01, inplace=True), 
            nn.MaxPool2d(2),                     # layer 4 128x64x64
            nn.Conv2d(128, 256, 3, 1, 1),        # layer 5 256x64x64
            nn.LeakyReLU(0.01, inplace=True),    # batch norm next
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2),                     # layer 6 256x32x32
            nn.Conv2d(256, 256, 3, 1, 1),        # layer 7 256x32x32
            nn.LeakyReLU(0.01, inplace=True),    # batch norm next
            nn.BatchNorm2d(256),
            nn.MaxPool2d(2),                     # layer 8 256x16x16
            nn.Conv2d(256, 256, 3, 1, 1),        # layer 9 256x16x16
            nn.LeakyReLU(0.01, inplace=True),    # batch norm next
            nn.BatchNorm2d(256),
            nn.Conv2d(256, 1, 3, 1, 1),          # layer 10 1x16x16
        )

    def forward(self, x,y):
        input = torch.cat([x,y], axis=1)
        return self.disc(input)
    
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): return n.cuda() 
    return n

# %%
# test_d = DiscriminatorNet(in_channels=2)
# x = torch.randn((16,1,256,256))
# out = test_d.forward(x,y)

# %%
discriminator = DiscriminatorNet(in_channels=2)
generator = GeneratorNet(in_channels=1, out_channels=1)

discriminator.cuda()
generator.cuda()
# Out:
# GeneratorNet(
#   (ups): ModuleList(
#     (0): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#     (1): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (2): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (3): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (4): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (5): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (6): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (7): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (downs): ModuleList(
#     (0): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (1): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (2): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (3): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): DoubleConv(
#     (conv): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (final_conv): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# ## loss function

# %%
# Optimizers
d_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))
g_optimizer = optim.Adam(generator.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Loss function
loss1 = nn.MSELoss()
loss2 = nn.BCELoss()
loss3 = nn.BCEWithLogitsLoss()

# Number of steps to apply to the discriminator
d_steps = 1  # In Goodfellow et. al 2014 this variable is assigned to 1
# Number of epochs
num_epochs = 15

# %% [markdown]
# ## train and validate

# %%
def test_noise():
  x,y = next(iter(data_loader))
  return Variable(x).float().cuda()

# %%
logger = Logger(model_name='DE-GAN', data_name='degrade')
num_test_samples = bs

for epoch in range(num_epochs):
    for n_batch, (degraded_batch, clean_batch) in enumerate(data_loader):

        real_data = clean_batch.float().cuda()
        noised_data = degraded_batch.float().cuda()
        
        # 1. Train Discriminator
        # Generate fake data
        fake_data = generator(noised_data)

        # Reset gradients
        d_optimizer.zero_grad()
        
        # 1.1 Train on Real Data
        prediction_real = discriminator(real_data, noised_data)

        # Calculate error and backpropagate
        real_data_target = torch.ones_like(prediction_real)
        loss_real = loss1(prediction_real, real_data_target)

        # 1.2 Train on Fake Data, you would need to add one more component
        prediction_fake = discriminator(fake_data, noised_data)

        # Calculate error and backpropagate
        fake_data_target = torch.zeros_like(prediction_real)
        loss_fake = loss1(prediction_fake, fake_data_target)

        loss_d = (loss_real + loss_fake)/2
        loss_d.backward(retain_graph=True)
        
        # 1.3 Update weights with gradients
        d_optimizer.step()
  
        # 2. Train Generator
        g_optimizer.zero_grad()

        # Sample noise and generate fake data
        prediction = discriminator(fake_data, real_data)
        
        # Calculate error and backpropagate
        real_data_target = torch.ones_like(prediction)
        #import pdb; pdb.set_trace();

        loss_g1 = loss1(prediction, real_data_target)
        loss_g2 = loss1(fake_data, real_data)*500
        loss_g = loss_g1 + loss_g2

        loss_g.backward()

        # Update weights with gradients
        g_optimizer.step()
                
        # Log error
        logger.log(loss_d, loss_g, epoch, n_batch, num_batches)

        # Display Progress
        if (n_batch) % 100 == 0:
            display.clear_output(True)
            # Display Images
            test_images = vectors_to_images(generator(test_noise())).data.cpu()
            logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
            # Display status Logs
            logger.display_status(
                epoch, num_epochs, n_batch, num_batches,
                loss_d, loss_g, prediction_real, prediction_fake
            )
        # Model Checkpoints
        logger.save_models(generator, discriminator, epoch)
# Out:
# Epoch: [14/15], Batch Num: [0/27]
# Discriminator Loss: 0.0039, Generator Loss: 112.9647
# D(x): 1.0147, D(G(z)): 0.0261

# %% [markdown]
# ## save model

# %%
torch.save(generator.state_dict(), path + 'generator-degrade-final2.pt')
torch.save(discriminator.state_dict(), path + 'discriminator-degrade-final2.pt')

# %% [markdown]
# ## inference

# %%
model = GeneratorNet(in_channels=1, out_channels=1)
model.load_state_dict(torch.load(path + 'generator-degrade-final2.pt'))
model.cuda()
model.eval()
# Out:
# GeneratorNet(
#   (ups): ModuleList(
#     (0): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#     (1): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (2): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (3): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (4): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (5): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (6): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (7): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (downs): ModuleList(
#     (0): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (1): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (2): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (3): DoubleConv(
#       (conv): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (bottleneck): DoubleConv(
#     (conv): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (final_conv): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
def calculate_psnr(img1, img2, max_value=255):
    """"Calculating peak signal-to-noise ratio (PSNR) between two images."""
    mse = np.mean((np.array(img1, dtype=np.float32) - np.array(img2, dtype=np.float32)) ** 2)
    if mse == 0:
        return 100
    return 20 * np.log10(max_value / (np.sqrt(mse)))

# %%
degrade_image, clean_image = next(iter(data_loader))
output = model(degrade_image.cuda().float())

psnr = calculate_psnr(degrade_image[0].detach().cpu(), output[0].detach().cpu())
print()
print('PSNR between Clean Image and Degrade Image: ', psnr)
print()
_, ax = plt.subplots(1,3, figsize=(22,10))
ax[0].imshow(degrade_image[0].squeeze(), cmap='gray')
ax[0].title.set_text('Degrade Image')
ax[1].imshow(output[0].detach().cpu().squeeze(), cmap='gray')
ax[1].title.set_text('Predicted Image')
ax[2].imshow(clean_image[0].detach().cpu().squeeze(), cmap='gray')
ax[2].title.set_text('Clean Image')
plt.show()
# Out:
# PSNR between Clean Image and Degrade Image:  52.80249183090365

# %% [markdown]
# ## PSNR of generated image

# %% [markdown]
# # Takeaways
#
# 1. CV and PIL show the images differently, PIL image looks sharper than CV

# %% [markdown]
# # References
#
# https://medium.com/ai-society/gans-from-scratch-1-a-deep-introduction-with-code-in-pytorch-and-tensorflow-cb03cdcdba0f
#
# https://github.com/diegoalejogm/gans
